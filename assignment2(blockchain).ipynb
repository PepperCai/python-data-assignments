# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('blockchain.csv') #read csv
#df.head()

# %%
# !pip install pyecharts
from pyecharts import Bar

# %%
df
# Out:
#      Unnamed: 0    author        date  favorite  thumb  \
# 0             0     小Q聊产品  2017/07/06        23      5
# 1             1      蓝狐笔记  2017/05/04        20      7
# 2             2      Anne  2017/04/25        42      7
# 3             3      蓝狐笔记  2016/10/20        66     11
# 4             4      蓝狐笔记  2016/10/18        42     15
# 5             5  人人都是产品经理  2016/10/17        64     10
# 6             6       亿欧网  2016/09/06        77     11
# 7             7       雷锋网  2016/09/02        33      1
# 8             8   清风徐来028  2016/01/29       109     20
# 9             9     小Q聊产品  2017/07/06        23      5
# 10           10      蓝狐笔记  2017/05/04        20      7
# 11           11      Anne  2017/04/25        42      7
# 12           12      蓝狐笔记  2016/10/20        66     11
# 13           13      蓝狐笔记  2016/10/18        42     15
# 14           14  人人都是产品经理  2016/10/17        64     10
# 15           15       亿欧网  2016/09/06        77     11
# ...

# %%
#看看点赞和喜欢的作者，哪些在前面，并且有个排序
pd_df2 = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False)
pd_df3 = df.groupby(['author'])['favorite'].mean().reset_index().sort_values("favorite",ascending=False)#作何byfavorite和thumb
attr = pd_df2.author
v1 = pd_df2.thumb  #you can pass a list like data here
v2 = pd_df3.favorite
bar = Bar("author by thumb and favorite")
bar.add("by thumb", attr, v1, mark_line=["average"])
bar.add("by favorite", attr, v2, mark_line=["average"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a391ecec762440038de9bed174d8855c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a391ecec762440038de9bed174d8855c = echarts.init(document.getElementById('a391ecec762440038de9bed174d8855c'), 'light', {renderer: 'canvas'});
#
# var option_a391ecec762440038de9bed174d8855c = {
#     "title": [
#         {
#             "text": "author by thumb and favorite",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
#看看各个作者出现的频次,哪些作者出现比较多

author =df['author'].value_counts().sort_values(ascending=False)
author_all = pd.DataFrame(author)
author_all
# Out:
#           author
# 蓝狐笔记          51
# 亿欧网           17
# 清风徐来028       17
# 人人都是产品经理      17
# Anne          17
# 小Q聊产品         17
# 雷锋网           17

# %%
plt.figure(figsize=(6,9))
labels = [u'蓝狐笔记',u'亿欧网',u'清风徐来028',u'人人都是产品经理',u'Anne']
sizes = [50,30,7,6,5]
colors = ['#F0E68C','#40b4e5','#FF7F50','#E0FFFF','#F5F5DC']
explode = (0.01,0,0,0,0)
patches,l_text,p_text = plt.pie(sizes,explode=explode,labels=labels,colors=colors,
                                labeldistance = 1.1,autopct = '%3.1f%%',shadow = False,
                                startangle = 90,pctdistance = 0.6)
plt.axis('equal')
plt.legend()
plt.show()

# %%
df
# Out:
#      Unnamed: 0    author        date  favorite  thumb  \
# 0             0     小Q聊产品  2017/07/06        23      5
# 1             1      蓝狐笔记  2017/05/04        20      7
# 2             2      Anne  2017/04/25        42      7
# 3             3      蓝狐笔记  2016/10/20        66     11
# 4             4      蓝狐笔记  2016/10/18        42     15
# 5             5  人人都是产品经理  2016/10/17        64     10
# 6             6       亿欧网  2016/09/06        77     11
# 7             7       雷锋网  2016/09/02        33      1
# 8             8   清风徐来028  2016/01/29       109     20
# 9             9     小Q聊产品  2017/07/06        23      5
# 10           10      蓝狐笔记  2017/05/04        20      7
# 11           11      Anne  2017/04/25        42      7
# 12           12      蓝狐笔记  2016/10/20        66     11
# 13           13      蓝狐笔记  2016/10/18        42     15
# 14           14  人人都是产品经理  2016/10/17        64     10
# 15           15       亿欧网  2016/09/06        77     11
# ...

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #set for displaying Chinese characters here.
plt.rcParams['axes.unicode_minus']=False #set for displaying `-`


author_counts=df['author'].value_counts()[:5].sort_values(ascending=False) #sort values
author = pd.DataFrame(author_counts)
fig = plt.figure(figsize=(14,7)) #adjust size
plt.bar(author.index, author.author,color = '#F0E68C',edgecolor = '#F0E68C') #change color of the bars

# another way to plot bar in pandas:
# country_counts=df['country'].value_counts()[:15].sort_values(ascending=False).plot(
#     kind='bar',color = '#46bc99',edgecolor = '#40b4e5')
plt.title('top 5 author') #plot title and label name
plt.xlabel('author')
plt.ylabel('author')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(30,20))


#plot country count
author = pd.DataFrame(df['author'].value_counts()[:15])
ax2 = country.plot(kind = 'bar',color = '#46bc99',edgecolor = '#40b4e5',ax=axes[0,1],fontsize=24)
ax2.set_title("author count",fontsize=40)



favorite_thumb = df[['favorite','thumb']]
ax4 = favorite_thumb.plot(kind = 'scatter',x='favorite',y='thumb',color = '#46bc99',ax=axes[1,1],s=80,fontsize=24)
ax4.set_title("Like with Bookmark count",fontsize=40)
# Out:
# Text(0.5,1,'Like with Bookmark count')
# /anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
